# %%
import sqlite3
from sqlite3 import Error

 
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by the db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        print(sqlite3.version)
    except Error as e:
        print(e)
 
    return conn

 
def select_all_tasks(conn):
    """
    Query all rows in the tasks table
    :param conn: the Connection object
    :return:
    """
    cur = conn.cursor()
    
    query1 = """
        SELECT *
        FROM FACILITIES
        """
    cur.execute(query1)
 
    rows = cur.fetchall()
 
    for row in rows:
        print(row)


def main():
    database = "sqlite_db_pythonsqlite.db"
 
    # create a database connection
    conn = create_connection(database)
    with conn: 
        print("2. Query all tasks")
        select_all_tasks(conn)
 
 
if __name__ == '__main__':
    main()
# Out:
# 2.6.0
# 2. Query all tasks
# (0, 'Tennis Court 1', 5, 25, 10000, 200)
# (1, 'Tennis Court 2', 5, 25, 8000, 200)
# (2, 'Badminton Court', 0, 15.5, 4000, 50)
# (3, 'Table Tennis', 0, 5, 320, 10)
# (4, 'Massage Room 1', 9.9, 80, 4000, 3000)
# (5, 'Massage Room 2', 9.9, 80, 4000, 3000)
# (6, 'Squash Court', 3.5, 17.5, 5000, 80)
# (7, 'Snooker Table', 0, 5, 450, 15)
# (8, 'Pool Table', 0, 5, 400, 15)

# %%
import sqlite3
from sqlite3 import Error

 
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by the db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        print(sqlite3.version)
    except Error as e:
        print(e)
 
    return conn

 
def select_all_tasks(conn):
    """
    Query all rows in the tasks table
    :param conn: the Connection object
    :return:
    """
    cur = conn.cursor()
    
    query1 = """
    SELECT name, revenue 
    FROM (
        SELECT facs.name, SUM(CASE 
        WHEN memid = 0 THEN slots * facs.guestcost
        ELSE slots * membercost
        END) AS revenue
    FROM Bookings 
    INNER JOIN.Facilities facs
    ON Bookings.facid = facs.facid
    GROUP BY facs.name
    ORDER BY revenue;
        """
    cur.execute(query1)
 
    rows = cur.fetchall()
 
    for row in rows:
        print(row)


def main():
    database = "sqlite_db_pythonsqlite.db"
 
    # create a database connection
    conn = create_connection(database)
    with conn: 
        print("2. Query all tasks")
        select_all_tasks(conn)
 
 
if __name__ == '__main__':
    main()
# Out:
# 2.6.0
# 2. Query all tasks
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-6-8e2b23cd35d8> in <module>
#      59
#      60 if __name__ == '__main__':
# ---> 61     main()
#
# <ipython-input-6-8e2b23cd35d8> in main()
#      55     with conn:
#      56         print("2. Query all tasks")
# ---> 57         select_all_tasks(conn)
#      58
#      59
#
# <ipython-input-6-8e2b23cd35d8> in select_all_tasks(conn)
#      40     ORDER BY revenue;
#      41         """
# ---> 42     cur.execute(query1)
#      43
#      44     rows = cur.fetchall()
#
# OperationalError: near ".": syntax error

# %%
import sqlite3
from sqlite3 import Error

 
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by the db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        print(sqlite3.version)
    except Error as e:
        print(e)
 
    return conn

 
def select_all_tasks(conn):
    """
    Query all rows in the tasks table
    :param conn: the Connection object
    :return:
    """
    cur = conn.cursor()
    
    query1 = """
    SELECT DISTINCT
  a.firstname || ' ' || a.surname AS member,
  CASE
    WHEN a.recommendedby IS NULL THEN NULL
	ELSE b.firstname || ' ' || b.surname 
  END AS recommender
FROM
  Members AS a,
  Members AS b
WHERE
  a.recommendedby IS NULL
  OR
  a.recommendedby=b.memid
ORDER BY
  member
        """
    cur.execute(query1)
 
    rows = cur.fetchall()
 
    for row in rows:
        print(row)


def main():
    database = "sqlite_db_pythonsqlite.db"
 
    # create a database connection
    conn = create_connection(database)
    with conn: 
        print("2. Query all tasks")
        select_all_tasks(conn)
 
 
if __name__ == '__main__':
    main()
# Out:
# 2.6.0
# 2. Query all tasks
# ('Anna Mackenzie', 'Darren Smith')
# ('Anne Baker', 'Ponder Stibbons')
# ('Charles Owen', 'Darren Smith')
# ('David Jones', 'Janice Joplette')
# ('David Pinker', 'Jemima Farrell')
# ('Douglas Jones', 'David Jones')
# ('Erica Crumpet', 'Tracy Smith')
# ('Florence Bader', 'Ponder Stibbons')
# ('Gerald Butters', 'Darren Smith')
# ('Henrietta Rumney', 'Matthew Genting')
# ('Henry Worthington-Smyth', 'Tracy Smith')
# ('Jack Smith', 'Darren Smith')
# ('Janice Joplette', 'Darren Smith')
# ('Joan Coplin', 'Timothy Baker')
# ('John Hunt', 'Millicent Purview')
# ('Matthew Genting', 'Gerald Butters')
# ('Millicent Purview', 'Tracy Smith')
# ('Nancy Dare', 'Janice Joplette')
# ('Ponder Stibbons', 'Burton Tracy')
# ('Ramnaresh Sarwin', 'Florence Bader')
# ('Tim Boothe', 'Tim Rownam')
# ('Timothy Baker', 'Jemima Farrell')

# %%
import sqlite3
from sqlite3 import Error

 
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by the db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        print(sqlite3.version)
    except Error as e:
        print(e)
 
    return conn

 
def select_all_tasks(conn):
    """
    Query all rows in the tasks table
    :param conn: the Connection object
    :return:
    """
    cur = conn.cursor()
    
    query1 = """
    SELECT Members.firstname as memfname, Members.surname as memsname, recs.firstname as recfname, recs.surname as recsname
	FROM 
		Members 
		LEFT OUTER JOIN MEMBERS.recommendedby 
			ON Members.memid = Members.recommendedby
order by memsname, memfname;          
        """
    cur.execute(query1)
 
    rows = cur.fetchall()
 
    for row in rows:
        print(row)


def main():
    database = "sqlite_db_pythonsqlite.db"
 
    # create a database connection
    conn = create_connection(database)
    with conn: 
        print("2. Query all tasks")
        select_all_tasks(conn)
 
 
if __name__ == '__main__':
    main()
# Out:
# 2.6.0
# 2. Query all tasks
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-9-b93a8e4530c5> in <module>
#      54
#      55 if __name__ == '__main__':
# ---> 56     main()
#
# <ipython-input-9-b93a8e4530c5> in main()
#      50     with conn:
#      51         print("2. Query all tasks")
# ---> 52         select_all_tasks(conn)
#      53
#      54
#
# <ipython-input-9-b93a8e4530c5> in select_all_tasks(conn)
#      35 order by memsname, memfname;
#      36         """
# ---> 37     cur.execute(query1)
#      38
#      39     rows = cur.fetchall()
#
# OperationalError: no such table: MEMBERS.recommendedby

# %%
import sqlite3
from sqlite3 import Error

 
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by the db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        print(sqlite3.version)
    except Error as e:
        print(e)
 
    return conn

 
def select_all_tasks(conn):
    """
    Query all rows in the tasks table
    :param conn: the Connection object
    :return:
    """
    cur = conn.cursor()
    
    query1 = """
        SELECT *
        FROM BOOKINGS
        ORDER BY slots
        """
        """
    cur.execute(query1)
 
    rows = cur.fetchall()
 
    for row in rows:
        print(row)


def main():
    database = "sqlite_db_pythonsqlite.db"
 
    # create a database connection
    conn = create_connection(database)
    with conn: 
        print("2. Query all tasks")
        select_all_tasks(conn)
 
 
if __name__ == '__main__':
    main()
# Out:
#   File "<ipython-input-11-a9565c1b8a62>", line 34
#     """
#     ^
# IndentationError: unexpected indent

# %%
import sqlite3
from sqlite3 import Error

 
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by the db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        print(sqlite3.version)
    except Error as e:
        print(e)
 
    return conn

 
def select_all_tasks(conn):
    """
    Query all rows in the tasks table
    :param conn: the Connection object
    :return:
    """
    cur = conn.cursor()
    
    query1 = """
        SELECT member, facility, cost from (
  SELECT
  m.firstname || ' ' || m.surname as member,
  f.name as facility,
  CASE WHEN m.memid = 0 THEN b.slots * f.guestcost
  ELSE b.slots * f.membercost END AS cost
  FROM Members AS m
  INNER JOIN Bookings AS b ON m.memid = b.memid
  INNER JOIN Facilities AS f ON b.facid = f.facid
  WHERE  b.starttime = '2012-09-14'
) as bookings
WHERE cost > 30
ORDER BY cost DESC;
        """
    cur.execute(query1)
 
    rows = cur.fetchall()
 
    for row in rows:
        print(row)


def main():
    database = "sqlite_db_pythonsqlite.db"
 
    # create a database connection
    conn = create_connection(database)
    with conn: 
        print("2. Query all tasks")
        select_all_tasks(conn)
 
 
if __name__ == '__main__':
    main()
# Out:
# 2.6.0
# 2. Query all tasks

# %%
#Answers double checked from https://pgexercises.com/questions/joins/self2.html
